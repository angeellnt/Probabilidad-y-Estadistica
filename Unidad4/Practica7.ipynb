# %% [markdown]
# <a href="https://colab.research.google.com/github/angeellnt/Probabilidad-y-Estadistica/blob/main/Unidad4/Practica7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 4
# **Practica 7. T Student**
#
# Facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Angel Alexander Rios Silva

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

data = np.array([118, 125, 130, 128, 122, 135, 126, 132, 129, 120, 127, 124])
n = len(data)
media = np.mean(data)
desv_std = np.std(data, ddof=1)
alpha = 0.05
df = n - 1

t_critico = t.ppf(1 - alpha/2, df)
error = t_critico * (desv_std / np.sqrt(n))

lim_inf = media - error
lim_sup = media + error

print(f"Media muestral = {media:.2f} mmHg")
print(f"Desviación estándar = {desv_std:.2f} mmHg")
print(f"Grados de libertad = {df}")
print(f"Valor crítico t = {t_critico:.3f}")
print(f"Intervalo de confianza 95%: [{lim_inf:.2f}, {lim_sup:.2f}] mmHg")

x = np.linspace(media - 4*desv_std, media + 4*desv_std, 200)
y = t.pdf((x - media) / (desv_std / np.sqrt(n)), df)

plt.figure(figsize=(8, 5))
plt.plot(x, y, color='navy', label='Distribución t de la media muestral')
plt.axvline(lim_inf, color='red', linestyle='--', label='Límite inferior')
plt.axvline(lim_sup, color='red', linestyle='--', label='Límite superior')
plt.axvline(media, color='green', linestyle='-', label='Media muestral')
plt.title("Intervalo de confianza del 95% para la media (t de Student)")
plt.xlabel("Presión arterial (mmHg)")
plt.ylabel("Densidad de probabilidad")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Media muestral = 126.33 mmHg
# Desviación estándar = 4.92 mmHg
# Grados de libertad = 11
# Valor crítico t = 2.201
# Intervalo de confianza 95%: [123.20, 129.46] mmHg
