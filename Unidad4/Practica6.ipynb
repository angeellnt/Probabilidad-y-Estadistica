# %% [markdown]
# <a href="https://colab.research.google.com/github/angeellnt/Probabilidad-y-Estadistica/blob/main/Unidad4/Practica6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 4
# **Practica 6**
#
# Facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Angel Alexander Rios Silva

# %%
from scipy.stats import poisson
mu = 5000 * 0.001
x = 4
prob = poisson.pmf(x, mu)
print(f"Media: {mu}")
print(f"Probabilidad: {prob}")
# Out:
# Media: 5.0
# Probabilidad: 0.17546736976785063
