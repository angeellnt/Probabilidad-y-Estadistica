# %% [markdown]
# <a href="https://colab.research.google.com/github/angeellnt/Probabilidad-y-Estadistica/blob/main/Unidad1/U1Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Angel Alexander Rios Silva
# ### **Programa 1: Estadistica basica e Histogramas**

# %%
from statistics import *
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96,]
print(grupoa)

promedio = sum(grupoa) /len(grupoa)
print(promedio)

promedio2 = mean(grupoa)
print(promedio2)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 75.33333333333333
# 75.33333333333333
