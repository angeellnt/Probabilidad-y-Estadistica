# %% [markdown]
# <a href="https://colab.research.google.com/github/angeellnt/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# **Practica 5**
#
# Facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Angel Alexander Rios Silva

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
from matplotlib import pyplot

# %%
covid = pd.read_csv("sample_data/20-06-30-COVID19MEXICO - codificado.csv", encoding = "ISO-8859-1")

covid.head()
# Out:
#    ï»¿ORIGEN  SECTOR    SEXO ENTIDAD_NAC  TIPO_PACIENTE FECHA_INGRESO  \
# 0          1       4  Hombre   Zacatecas  Hospitalizado    27/03/2020
# 1          1      12  Hombre   Zacatecas  Hospitalizado    06/04/2020
# 2          1      12   Mujer   Zacatecas  Hospitalizado    15/04/2020
# 3          2      12   Mujer   Zacatecas  Hospitalizado    08/05/2020
# 4          2      12   Mujer   Zacatecas  Hospitalizado    08/05/2020
#
#   FECHA_SINTOMAS   FECHA_DEF INTUBADO NEUMONIA  ...  EPOC ASMA INMUSUPR  \
# 0     27/03/2020  9999-99-99       No       No  ...    No   No       No
# 1     02/04/2020  9999-99-99       No       Si  ...    No   No       No
# 2     12/04/2020  9999-99-99       No       Si  ...    No   No       Si
# 3     08/05/2020  9999-99-99       Si       No  ...    No   No       No
# 4     08/05/2020  9999-99-99       Si       No  ...    No   No       No
#
#   HIPERTENSION CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO RESULTADO UCI
# 0           No             No       No            No         No  Negativo  No
# 1           No             No       No            No         No  Negativo  No
# 2           No             No       No            No         No  Negativo  No
# 3           No             No       No            No         No  Negativo  Si
# 4           No             No       No            No         No  Negativo  Si
#
# [5 rows x 23 columns]

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78346 entries, 0 to 78345
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ï»¿ORIGEN       78346 non-null  int64
#  1   SECTOR          78346 non-null  int64
#  2   SEXO            78346 non-null  object
#  3   ENTIDAD_NAC     78346 non-null  object
#  4   TIPO_PACIENTE   78346 non-null  object
#  5   FECHA_INGRESO   78346 non-null  object
#  6   FECHA_SINTOMAS  78346 non-null  object
#  7   FECHA_DEF       78345 non-null  object
#  8   INTUBADO        78345 non-null  object
#  9   NEUMONIA        78345 non-null  object
#  10  EDAD            78345 non-null  float64
#  11  EMBARAZO        78345 non-null  object
#  12  DIABETES        78345 non-null  object
#  13  EPOC            78345 non-null  object
#  14  ASMA            78345 non-null  object
#  15  INMUSUPR        78345 non-null  object
#  16  HIPERTENSION    78345 non-null  object
#  17  CARDIOVASCULAR  78345 non-null  object
#  18  OBESIDAD        78345 non-null  object
#  19  RENAL_CRONICA   78345 non-null  object
#  20  TABAQUISMO      78345 non-null  object
#  21  RESULTADO       78345 non-null  object
#  22  UCI             78345 non-null  object
# dtypes: float64(1), int64(2), object(20)
# memory usage: 13.7+ MB

# %%
covid.EDAD.max()
# Out:
# 27.0

# %%
covid.EDAD.min()
# Out:
# 0.0

# %%
media = covid.EDAD.mean()
plt.pyplot.hist(covid.EDAD, bins=11)
plt.pyplot.title("Histograma Edad Pruebas COVID")
plt.pyplot.axvline(media, color='y', linestyle='dashed', linewidth=2, label=f'Media={media:.2f}')
plt.pyplot.xlabel("Edad")
plt.pyplot.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
plt.pyplot.hist(covid.SEXO, bins=3)
plt.pyplot.title("Histograma Sexo Pruebas COVID")
plt.pyplot.xlabel("Sexo")
plt.pyplot.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
plt.pyplot.hist(covid.TIPO_PACIENTE, bins=3)
plt.pyplot.title("Histograma Tipo Paciente Pruebas COVID")
plt.pyplot.xlabel("Tipo Paciente")
plt.pyplot.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
sns.boxplot(x="SEXO", y="EDAD", data=covid)
# Out:
# <Axes: xlabel='SEXO', ylabel='EDAD'>

# %%
sns.boxplot(x="TIPO_PACIENTE", y="EDAD", data=covid)
# Out:
# <Axes: xlabel='TIPO_PACIENTE', ylabel='EDAD'>

# %%
sns.boxplot(x="RESULTADO", y="EDAD", data=covid)
# Out:
# <Axes: xlabel='RESULTADO', ylabel='EDAD'>
