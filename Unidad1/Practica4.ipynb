# %% [markdown]
# <a href="https://colab.research.google.com/github/angeellnt/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as ptl
from statistics import *

fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [83.83, 89.69, 65.1, 58.24, 53.26, 87.02, 54.42, 55.18, 60.16, 66.6, 51.1, 72.0, 81.37, 94.01, 93.59, 91.72, 93.84, 63.74, 79.03, 98.74, 88.98, 76.82, 62.06, 64.24, 76.93, 62.69, 97.23, 79.42, 71.6, 76.03, 69.18, 85.96, 77.02, 86.54, 55.13, 60.36, 98.98, 55.87, 75.69, 93.54, 74.05, 57.62, 92.37, 76.24, 74.47, 88.59, 80.37, 88.24, 99.08, 63.83, 74.58, 56.94, 77.58, 86.76, 94.21, 97.67, 58.94, 61.46, 90.31, 95.18, 96.71, 81.5, 52.1, 99.04, 79.01, 58.95, 59.13, 64.85, 72.62, 66.47, 68.68, 96.14, 67.2, 85.82, 63.5, 81.32, 80.06, 57.5, 95.24, 87.77, 97.66, 81.09, 86.3, 82.84, 89.05, 77.85, 83.67, 71.01, 56.6, 59.72, 85.09, 59.25, 93.23, 78.42, 75.24, 94.51, 76.19, 70.2, 90.03, 59.41]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [83.47, 63.59, 81.46, 52.28, 68.4, 78.35, 41.79, 91.56, 88.54, 57.06, 66.25, 47.59, 67.97, 88.21, 55.9, 72.21, 75.19, 91.84, 50.61, 45.08, 44.53, 77.82, 41.53, 69.44, 48.05, 92.81, 79.32, 88.03, 64.01, 54.47, 88.91, 74.91, 50.2, 47.05, 54.51, 84.32, 65.43, 70.1, 74.79, 41.52, 82.73, 43.24, 42.92, 79.11, 66.57, 45.85, 75.66, 41.5, 77.08, 42.0, 74.44, 61.37, 81.32, 56.04, 65.23, 76.52, 78.26, 75.64, 84.42, 42.34, 55.3, 48.14, 40.46, 40.85, 40.37, 61.52, 50.21, 65.28, 51.29, 92.36, 72.25, 54.42, 66.95, 69.9, 64.89, 50.71, 70.51, 65.63, 56.13, 79.34, 89.61, 82.58, 66.29, 50.16, 71.68, 47.49, 58.12, 52.83, 70.55, 46.51, 56.9, 90.58, 66.6, 86.49, 57.64, 61.11, 50.93, 75.6, 56.5, 75.35]

# %%
ptl.boxplot(fabrica1)
ptl.ylabel('Producción en mts.')
ptl.title('Producción de la fabrica 1')
ptl.show()

# %%
fig, (ax1, ax2) = ptl.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Producción de la fabrica 1')
bplot2 = ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Producción de la fabrica 2')
ptl.show()

# %%
fabrica1.append(150)
print(fabrica1)
# Out:
# [83.83, 89.69, 65.1, 58.24, 53.26, 87.02, 54.42, 55.18, 60.16, 66.6, 51.1, 72.0, 81.37, 94.01, 93.59, 91.72, 93.84, 63.74, 79.03, 98.74, 88.98, 76.82, 62.06, 64.24, 76.93, 62.69, 97.23, 79.42, 71.6, 76.03, 69.18, 85.96, 77.02, 86.54, 55.13, 60.36, 98.98, 55.87, 75.69, 93.54, 74.05, 57.62, 92.37, 76.24, 74.47, 88.59, 80.37, 88.24, 99.08, 63.83, 74.58, 56.94, 77.58, 86.76, 94.21, 97.67, 58.94, 61.46, 90.31, 95.18, 96.71, 81.5, 52.1, 99.04, 79.01, 58.95, 59.13, 64.85, 72.62, 66.47, 68.68, 96.14, 67.2, 85.82, 63.5, 81.32, 80.06, 57.5, 95.24, 87.77, 97.66, 81.09, 86.3, 82.84, 89.05, 77.85, 83.67, 71.01, 56.6, 59.72, 85.09, 59.25, 93.23, 78.42, 75.24, 94.51, 76.19, 70.2, 90.03, 59.41, 150]

# %%
fig,(ax1,ax2) = ptl.subplots(nrows=1,ncols=2,figsize=(9,4))
bplot1 = ax1.boxplot(fabrica1,vert=True,patch_artist=True)
ax1.set_title('Producción de la fabrica 1')
bplot2 = ax2.boxplot(fabrica2,vert=True,patch_artist=True)
ax2.set_title('Producción de la fabrica 2')
ptl.show()

# %%
fig,(ax1,ax2) = ptl.subplots(nrows=1,ncols=2,figsize=(9,5))
bplot1 = ax1.boxplot(fabrica1,vert=True,patch_artist=True)
ax1.set_title('Producción de la fabrica 1')
ax1.set_ylim(30, 160)
bplot2 = ax2.boxplot(fabrica2,vert=True,patch_artist=True)
ax2.set_title('Producción de la fabrica 2')
ax2.set_ylim(30, 160)
ptl.show()
