# %% [markdown]
# <a href="https://colab.research.google.com/github/angeellnt/Probabilidad-y-Estadistica/blob/main/Unidad2/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 2
# **Practica 2**
#
# Facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Angel Alexander Rios Silva

# %%
import math as mt
from itertools import permutations
from itertools import product
import numpy as np

# %%
mt.factorial(7)
# Out:
# 5040

# %%
mt.factorial(4)
# Out:
# 24

# %%
5040 / 24
# Out:
# 210.0

# %%
nombres = ["a", "b", "c", "d", "e", "f", "g"]
n = len(nombres)
r = 3

Pr = mt.factorial(n) / (mt.factorial(n-r))

print("Existen", Pr , " posibles permutaciones sin repeticion del total de ", n ," nombres ", " en grupos de ", r ," en ", r)

print("Aqui las permutaciones")
permutaciones_nombres = list(permutations(nombres, r))
for permutacion in permutaciones_nombres:
    print(permutacion)
